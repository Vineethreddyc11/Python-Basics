# %% [markdown]
# # Python Operators

# %% [markdown]
# - Operators are special symbols in pyhton that carry out Arithmetic or Logical computation. The value that the operator operates on is called the OPERAND.

# %% [markdown]
# ## Types of Operators :

# %% [markdown]
# - 1. Arithmetic Operators
# - 2. Comparison(Relational) Operators
# - 3. Assignment Operators
# - 4. Logical Operators
# - 5. Bitwise Operators
# - 6. Membership Operators
# - 7. Identity Operators

# %% [markdown]
# ### 1. Arithmetic Operators:

# %% [markdown]
# - Arithmetic Operators are used to perform mathematical operations like Addition, Subtraction, Multiplication etc

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 25
b = 9

# %%
a+b
# Out:
# 34

# %%
a-b
# Out:
# 16

# %%
a*b
# Out:
# 225

# %%
a/b
# Out:
# 2.7777777777777777

# %%
a%b
# Out:
# 7

# %%
a//b
# Out:
# 2

# %%
a**b
# Out:
# 3814697265625

# %% [markdown]
# ### 2. Comparison Operators:

# %% [markdown]
# - Comparison Operators are used to compare values. It returns either TRUE or FALSE according to the condition.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 9
b = 25

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a >= b
# Out:
# False

# %%
a <= b
# Out:
# True

# %% [markdown]
# ### 3. Assignment Operators:

# %% [markdown]
# - Assignment operators are used in python to assign vales to variables.
# - There are various compound operators in Python like a += 5 that adds to the variable and later assigns the same. It is equivalent to a = a + 5.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
c = 5
c
# Out:
# 5

# %%
c += 5  # c = c+5 = 5+5
c
# Out:
# 10

# %%
c -= 5  # c = c-5 = 10-5
c
# Out:
# 5

# %%
c *= 10  # c = c*10 = 5*10
c
# Out:
# 50

# %%
c /= 2  # c = c/2 = 50/2
c
# Out:
# 25.0

# %%
c %= 4
c
# Out:
# 1.0

# %%
c **= 5
c
# Out:
# 1.0

# %%
c = 25
c //= 2
c
# Out:
# 12

# %% [markdown]
# ### 4. Logical Operators:

# %% [markdown]
# - Logical Operators are the AND, OR, NOT Operators.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = True
y = False

# %%
x and y
# Out:
# False

# %%
x or y
# Out:
# True

# %%
not x
# Out:
# False

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 5
b = 4

# %%
a<8 and b>2
# Out:
# True

# %%
a<8 or b<8
# Out:
# True

# %%
not a <8
# Out:
# False

# %% [markdown]
# ### 5. Bitwise Operators:

# %% [markdown]
# - Bitwise operators act on operands as if they were strings of binary digits. They operate bit by bit, hence the name.
# - Assume if a = 60; and b = 13; Now in the binary format their values will be 0011 1100 and 0000 1101 respectively. Following table lists out the bitwise operators supported by Python language with an example each in those, we use the above two variables (a and b) as operands −
#
# a = 0011 1100
#
# b = 0000 1101
#
#
# a&b = 0000 1100
#
# a|b = 0011 1101
#
# a^b = 0011 0001
#
# ~a  = 1100 0011

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 60
b = 13

# %%
a & b
# Out:
# 12

# %%
a | b
# Out:
# 61

# %%
a ^ b
# Out:
# 49

# %%
~a
# Out:
# -61

# %%
a << 2
# Out:
# 240

# %% [markdown]
# a >> 2

# %% [markdown]
# ### 6. Membership Operators:

# %% [markdown]
# - in and not in are the membership operators in Python. They are used to test whether a value or variable is found in a sequence (string, list, tuple, set and dictionary).
#
# - In a dictionary we can only test for presence of key, not the value.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = [1,3,4,5,6]
y = [22,85,91]

# %%
5 in x
# Out:
# True

# %%
6 not in y
# Out:
# True

# %%
99 in x
# Out:
# False

# %%
22 not in y
# Out:
# False

# %% [markdown]
# ### 7. Identity Operators:

# %% [markdown]
# - is and is not are the identity operators in Python. They are used to check if two values (or variables) are located on the same part of the memory. Two variables that are equal does not imply that they are identical.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x1 = 5
y1 = 5
x2 = 'Hello'
y2 = 'Hello'
x3 = [1,2,3]
y3 = [1,2,3]

# %%
id(x1)
# Out:
# 1689377056

# %%
id(y1)
# Out:
# 1689377056

# %%
x1 is y1
# Out:
# True

# %%
x1 is x2
# Out:
# False

# %%
x1 is not x2
# Out:
# True
